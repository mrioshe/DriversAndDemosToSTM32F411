# %%
from PIL import Image
from io import BytesIO
import pandas as pd

# %%
def resize_image(input_image, output_image, target_resolution=(640, 480)):
    try:
        # Open the input image
        with Image.open(input_image) as img:
            # Resize the image
            resized_img = img.resize(target_resolution)

            # Save the resized image
            resized_img.save(output_image)
            print(f"Image resized and saved to {output_image}")

    except Exception as e:
        print(f"Error: {e}")

# %%
def convert_to_3bit_grayscale(input_image, output_image):
    try:
        # Open the input image
        with Image.open(input_image) as img:
            # Convert the image to 3-bit grayscale
            three_bit_img = img.convert('L', palette=Image.ADAPTIVE, colors=8)

            # Save the 3-bit grayscale image
            three_bit_img.save(output_image)
            print(f"Image converted to 3-bit grayscale and saved to {output_image}")

    except Exception as e:
        print(f"Error: {e}")

# %%
def image_to_dataframe_3bit_inverted(image_path):
    try:
        # Open the 3-bit grayscale image
        with Image.open(image_path) as img:
            # Convert the image to 3-bit grayscale
            img = img.convert('L', palette=Image.ADAPTIVE, colors=8)

            # Get pixel data
            pixels = list(img.getdata())

            # Get image size
            width, height = img.size

            # Create a DataFrame with pixel information
            df = pd.DataFrame(pixels, columns=["Pixel_Value"])

            # Invert the pixel values
            df["Pixel_Value"] = 7 - (df["Pixel_Value"] // 32)

            # Add columns for X and Y coordinates
            df["X"] = [i % width for i in range(len(pixels))]
            df["Y"] = [i // width for i in range(len(pixels))]

            print("DataFrame created successfully.")
            return df

    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
def export_dataframe_to_excel(dataframe, output_excel_path):
    try:
        # Export the DataFrame to Excel
        dataframe.to_excel(output_excel_path, index=False)

        print(f"DataFrame exported to {output_excel_path}")

    except Exception as e:
        print(f"Error: {e}")

# %%
def clean_and_organize_data(pixel_df):
    try:
        # Clean the data
        cleaned_df = pixel_df[pixel_df.groupby('Y')['Pixel_Value'].transform('sum') > 0]

        # Organize pixel values into a matrix
        organized_matrix = cleaned_df.pivot(index='Y', columns='X', values='Pixel_Value')

        return organized_matrix

    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
# Call the functions
resize_image("imagesToEngraving/image.png", "imagesResized/imageResized.png")
convert_to_3bit_grayscale("imagesResized/imageResized.png", "grayScaledImages/grayScaledImage.png")
pixel_df_3bit_inverted = image_to_dataframe_3bit_inverted("grayScaledImages/grayScaledImage.png")
if pixel_df_3bit_inverted is not None:
    print(pixel_df_3bit_inverted.head())
cleaned_matrix = clean_and_organize_data(pixel_df_3bit_inverted)
# Out:
# Image resized and saved to imagesResized/imageResized.png
# Image converted to 3-bit grayscale and saved to grayScaledImages/grayScaledImage.png
# DataFrame created successfully.
#    Pixel_Value  X  Y
# 0            0  0  0
# 1            0  1  0
# 2            0  2  0
# 3            0  3  0
# 4            0  4  0

# %%
len(cleaned_matrix)
# Out:
# 451

# %%
export_dataframe_to_excel(pixel_df_3bit_inverted, "dataFrameToExcel/data.xlsx")
cleaned_matrix = clean_and_organize_data(pixel_df_3bit_inverted)
export_dataframe_to_excel(cleaned_matrix,"dataFrameToExcel/data2.xlsx")
# Out:
# DataFrame exported to dataFrameToExcel/data.xlsx
# DataFrame exported to dataFrameToExcel/data2.xlsx

# %%
import serial

# %%
ser = serial.Serial('/dev/ttyS0', 921600)
data1=0
data2=0
data1=ser.read()
print(data1)
ser.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/mauricio/Documents/GitHub/mrioshe_tallerV/python/3dbitImageSerialCommunication.ipynb Cell 11 line 4
#       <a href='vscode-notebook-cell:/home/mauricio/Documents/GitHub/mrioshe_tallerV/python/3dbitImageSerialCommunication.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> data1=0
#       <a href='vscode-notebook-cell:/home/mauricio/Documents/GitHub/mrioshe_tallerV/python/3dbitImageSerialCommunication.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> data2=0
# ----> <a href='vscode-notebook-cell:/home/mauricio/Documents/GitHub/mrioshe_tallerV/python/3dbitImageSerialCommunication.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> data1=ser.read()
#       <a href='vscode-notebook-cell:/home/mauricio/Documents/GitHub/mrioshe_tallerV/python/3dbitImageSerialCommunication.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> print(data1)
#       <a href='vscode-notebook-cell:/home/mauricio/Documents/GitHub/mrioshe_tallerV/python/3dbitImageSerialCommunication.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> ser.close()
#
# File /usr/lib/python3/dist-packages/serial/serialposix.py:565, in Serial.read(self, size)
#     563 while len(read) < size:
#     564     try:
# --> 565         ready, _, _ = select.select([self.fd, self.pipe_abort_read_r], [], [], timeout.time_left())
#     566         if self.pipe_abort_read_r in ready:
#     567             os.read(self.pipe_abort_read_r, 1000)
#
# KeyboardInterrupt:

# %%
len(cleaned_matrix.iloc[0])
# Out:
# 640

# %%
cleaned_matrix.iloc[0][639]
# Out:
# 0

# %%
len(cleaned_matrix.iloc[j])
# Out:
# 640

# %%
cleaned_matrix.iloc[0][0]=1

# %%
ser = serial.Serial('/dev/ttyACM0', 921600)
data1 = 0
data2 = 0

while True:
    data1 = ser.read(1)
    if data1.decode('utf-8') == 's':
        print("Comenzando comunicación")
        for i in range(len(cleaned_matrix.iloc[0])-1):
            dataAux=str(cleaned_matrix.iloc[0][i])
            ser.write(dataAux.encode())
            while True:
                data2=ser.read(1)
                if (data2.decode('utf-8')=='c'):
                    print('Dato ', i, ' de la fila ', 0, ' leído por el micro. El dato es: ', dataAux.encode())
                    break;
        print("La comunicación finalizó")   
        ser.close()
        break
# Out:
# Comenzando comunicación
# Dato  0  de la fila  0  leído por el micro. El dato es:  b'1'
# Dato  1  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  2  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  3  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  4  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  5  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  6  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  7  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  8  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  9  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  10  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  11  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  12  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  13  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  14  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  15  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  16  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  17  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  18  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  19  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  20  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  21  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  22  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  23  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  24  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  25  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  26  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  27  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  28  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  29  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  30  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  31  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  32  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  33  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  34  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  35  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  36  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  37  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  38  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  39  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  40  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  41  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  42  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  43  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  44  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  45  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  46  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  47  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  48  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  49  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  50  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  51  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  52  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  53  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  54  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  55  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  56  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  57  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  58  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  59  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  60  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  61  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  62  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  63  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  64  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  65  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  66  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  67  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  68  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  69  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  70  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  71  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  72  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  73  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  74  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  75  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  76  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  77  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  78  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  79  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  80  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  81  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  82  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  83  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  84  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  85  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  86  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  87  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  88  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  89  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  90  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  91  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  92  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  93  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  94  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  95  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  96  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  97  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  98  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  99  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  100  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  101  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  102  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  103  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  104  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  105  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  106  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  107  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  108  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  109  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  110  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  111  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  112  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  113  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  114  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  115  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  116  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  117  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  118  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  119  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  120  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  121  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  122  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  123  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  124  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  125  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  126  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  127  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  128  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  129  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  130  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  131  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  132  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  133  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  134  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  135  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  136  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  137  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  138  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  139  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  140  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  141  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  142  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  143  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  144  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  145  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  146  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  147  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  148  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  149  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  150  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  151  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  152  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  153  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  154  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  155  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  156  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  157  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  158  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  159  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  160  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  161  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  162  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  163  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  164  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  165  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  166  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  167  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  168  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  169  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  170  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  171  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  172  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  173  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  174  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  175  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  176  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  177  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  178  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  179  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  180  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  181  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  182  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  183  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  184  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  185  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  186  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  187  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  188  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  189  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  190  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  191  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  192  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  193  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  194  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  195  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  196  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  197  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  198  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  199  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  200  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  201  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  202  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  203  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  204  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  205  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  206  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  207  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  208  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  209  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  210  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  211  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  212  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  213  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  214  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  215  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  216  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  217  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  218  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  219  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  220  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  221  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  222  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  223  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  224  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  225  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  226  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  227  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  228  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  229  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  230  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  231  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  232  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  233  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  234  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  235  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  236  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  237  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  238  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  239  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  240  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  241  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  242  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  243  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  244  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  245  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  246  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  247  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  248  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  249  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  250  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  251  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  252  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  253  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  254  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  255  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  256  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  257  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  258  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  259  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  260  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  261  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  262  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  263  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  264  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  265  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  266  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  267  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  268  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  269  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  270  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  271  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  272  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  273  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  274  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  275  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  276  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  277  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  278  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  279  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  280  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  281  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  282  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  283  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  284  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  285  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  286  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  287  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  288  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  289  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  290  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  291  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  292  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  293  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  294  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  295  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  296  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  297  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  298  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  299  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  300  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  301  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  302  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  303  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  304  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  305  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  306  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  307  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  308  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  309  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  310  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  311  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  312  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  313  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  314  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  315  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  316  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  317  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  318  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  319  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  320  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  321  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  322  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  323  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  324  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  325  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  326  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  327  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  328  de la fila  0  leído por el micro. El dato es:  b'3'
# Dato  329  de la fila  0  leído por el micro. El dato es:  b'3'
# Dato  330  de la fila  0  leído por el micro. El dato es:  b'3'
# Dato  331  de la fila  0  leído por el micro. El dato es:  b'2'
# Dato  332  de la fila  0  leído por el micro. El dato es:  b'2'
# Dato  333  de la fila  0  leído por el micro. El dato es:  b'2'
# Dato  334  de la fila  0  leído por el micro. El dato es:  b'2'
# Dato  335  de la fila  0  leído por el micro. El dato es:  b'2'
# Dato  336  de la fila  0  leído por el micro. El dato es:  b'1'
# Dato  337  de la fila  0  leído por el micro. El dato es:  b'1'
# Dato  338  de la fila  0  leído por el micro. El dato es:  b'1'
# Dato  339  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  340  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  341  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  342  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  343  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  344  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  345  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  346  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  347  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  348  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  349  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  350  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  351  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  352  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  353  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  354  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  355  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  356  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  357  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  358  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  359  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  360  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  361  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  362  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  363  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  364  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  365  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  366  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  367  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  368  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  369  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  370  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  371  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  372  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  373  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  374  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  375  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  376  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  377  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  378  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  379  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  380  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  381  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  382  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  383  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  384  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  385  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  386  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  387  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  388  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  389  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  390  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  391  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  392  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  393  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  394  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  395  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  396  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  397  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  398  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  399  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  400  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  401  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  402  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  403  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  404  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  405  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  406  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  407  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  408  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  409  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  410  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  411  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  412  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  413  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  414  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  415  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  416  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  417  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  418  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  419  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  420  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  421  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  422  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  423  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  424  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  425  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  426  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  427  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  428  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  429  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  430  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  431  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  432  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  433  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  434  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  435  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  436  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  437  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  438  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  439  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  440  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  441  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  442  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  443  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  444  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  445  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  446  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  447  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  448  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  449  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  450  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  451  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  452  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  453  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  454  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  455  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  456  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  457  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  458  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  459  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  460  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  461  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  462  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  463  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  464  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  465  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  466  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  467  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  468  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  469  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  470  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  471  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  472  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  473  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  474  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  475  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  476  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  477  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  478  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  479  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  480  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  481  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  482  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  483  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  484  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  485  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  486  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  487  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  488  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  489  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  490  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  491  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  492  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  493  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  494  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  495  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  496  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  497  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  498  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  499  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  500  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  501  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  502  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  503  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  504  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  505  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  506  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  507  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  508  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  509  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  510  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  511  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  512  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  513  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  514  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  515  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  516  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  517  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  518  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  519  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  520  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  521  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  522  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  523  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  524  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  525  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  526  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  527  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  528  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  529  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  530  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  531  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  532  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  533  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  534  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  535  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  536  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  537  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  538  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  539  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  540  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  541  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  542  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  543  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  544  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  545  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  546  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  547  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  548  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  549  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  550  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  551  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  552  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  553  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  554  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  555  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  556  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  557  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  558  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  559  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  560  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  561  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  562  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  563  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  564  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  565  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  566  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  567  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  568  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  569  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  570  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  571  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  572  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  573  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  574  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  575  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  576  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  577  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  578  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  579  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  580  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  581  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  582  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  583  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  584  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  585  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  586  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  587  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  588  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  589  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  590  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  591  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  592  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  593  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  594  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  595  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  596  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  597  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  598  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  599  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  600  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  601  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  602  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  603  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  604  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  605  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  606  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  607  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  608  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  609  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  610  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  611  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  612  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  613  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  614  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  615  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  616  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  617  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  618  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  619  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  620  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  621  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  622  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  623  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  624  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  625  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  626  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  627  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  628  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  629  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  630  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  631  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  632  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  633  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  634  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  635  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  636  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  637  de la fila  0  leído por el micro. El dato es:  b'0'
# Dato  638  de la fila  0  leído por el micro. El dato es:  b'0'
# La comunicación finalizó

# %%
cleaned_matrix.iloc[0][639]
# Out:
# 0

# %%
for j in range(len(cleaned_matrix)):
            if (j%2==0):
                for i in range(len(cleaned_matrix.iloc[j])):
                    ser.write(str(cleaned_matrix.iloc[j][i]))
                    while True:
                        data2=ser.read(1)
                        if (data2.decode('utf-8')=='c'):
                            break;
            elif (j%2==1):
                for i in range(len(cleaned_matrix.iloc[j])):
                    ser.write(str(cleaned_matrix.iloc[j][len(cleaned_matrix.iloc[j])-i]))
                    while(True):
                        data2=ser.read(1)
                        if (data2.decode('utf-8')=='c'):
                            break;
        print("La comunicación finalizó")   
        ser.close()
        break

# %%
        for j in range(len(cleaned_matrix)):
            if (j%2==0):
                for i in range(len(cleaned_matrix.iloc[j])):
                    ser.write(str(cleaned_matrix.iloc[j][i]))
                    while(True):
                        data2=ser.readline().decode('utf-8').strip()
                        if (data2=='c'):
                            break;
            elif (j%2==1):
                  for i in range(len(cleaned_matrix.iloc[j])):
                        ser.write(str(cleaned_matrix.iloc[j][len(cleaned_matrix.iloc[j])-i]))
            while(True):
                    data2=ser.readline().decode('utf-8').strip()
            if (data2=='c'):
                  break;
    print("La comunicación finalizó")
    break;

# %%
data1
# Out:
# 0

# %%
range(649)
# Out:
# range(0, 649)

# %%
str(2)
# Out:
# '2'

# %%
ser = serial.Serial('/dev/ttyACM0', 921600)
data1 = 0
data2 = 0

while True:
    data1 = ser.read(1)
    if data1.decode('utf-8') == 's':
        print("Comenzando comunicación")
        for j in range(len(cleaned_matrix)-1):
            if (j%2==0):
                for i in range(len(cleaned_matrix.iloc[j])-1):
                    dataAux=str(cleaned_matrix.iloc[j][i])
                    ser.write(dataAux.encode())
                    while True:
                        data2=ser.read(1)
                        if (data2.decode('utf-8')=='c'):
                            print('Dato ', i, ' de la fila ', j, ' leído por el micro. El dato es: ', cleaned_matrix.iloc[j][i])
                            break;
            elif (j%2==1):
                for i in range(len(cleaned_matrix.iloc[j])-1):
                    dataAux=str(cleaned_matrix.iloc[j][len(cleaned_matrix.iloc[j])-i])
                    ser.write(dataAux.encode())
                    while(True):
                        data2=ser.read(1)
                        if (data2.decode('utf-8')=='c'):
                            print('Dato ', i, ' de la fila ', j, ' leído por el micro. El dato es: ', cleaned_matrix.iloc[j][i])
                            break;
        print("La comunicación finalizó")   
        ser.close()
        break

# %%
import subprocess

# %%
subprocess.run(["python", "communicationFunctions.py"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/mauricio/Documents/GitHub/mrioshe_tallerV/python/3dbitImageSerialCommunication.ipynb Cell 25 line 1
# ----> <a href='vscode-notebook-cell:/home/mauricio/Documents/GitHub/mrioshe_tallerV/python/3dbitImageSerialCommunication.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> subprocess.run(["python", "communicationFunctions.py"])
#
# File /usr/lib/python3.10/subprocess.py:503, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     500     kwargs['stdout'] = PIPE
#     501     kwargs['stderr'] = PIPE
# --> 503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
#     505         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File /usr/lib/python3.10/subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     967         if self.text_mode:
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#     982     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /usr/lib/python3.10/subprocess.py:1863, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1861     if errno_num != 0:
#    1862         err_msg = os.strerror(errno_num)
# -> 1863     raise child_exception_type(errno_num, err_msg, err_filename)
#    1864 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python'
